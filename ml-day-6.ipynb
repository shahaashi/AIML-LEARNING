# %% [markdown]
# Day 6 — Problem Statement
#
# Implement Linear Regression Using scikit-learn
#
# Objective: build the standard ML workflow using a library, instead of writing gradient descent manually.
#
# You already understand the math. Now you will use the industry tool that performs those steps internally.
#
# Dataset
#
# Use the same dataset.
#
# import numpy as np
#
# X = np.array([
#     [1000, 3],
#     [1200, 4],
#     [1500, 4],
#     [1800, 5]
# ])
#
# y = np.array([50, 60, 70, 80])
#
# Here:
#
# features (X) → size, rooms
#
# target (y) → price
#
# Step 1 — Split the Dataset
#
# We divide the data into training and testing sets.
#
# from sklearn.model_selection import train_test_split
#
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.25, random_state=42
# )
#
# Meaning:
#
# 75% training
#
# 25% testing
#
# Step 2 — Create the Model
# from sklearn.linear_model import LinearRegression
#
# model = LinearRegression()
#
# This creates the regression model.
#
# Step 3 — Train the Model
# model.fit(X_train, y_train)
#
# Internally, scikit-learn finds the optimal weights and bias.
#
# Step 4 — Make Predictions
# y_pred = model.predict(X_test)
#
# Now the model predicts prices for unseen data.
#
# Step 5 — Evaluate the Model
# from sklearn.metrics import mean_squared_error
#
# mse = mean_squared_error(y_test, y_pred)
#
# print("Mean Squared Error:", mse)
#
# Lower error → better model.
#
# Step 6 — Inspect the Learned Parameters
# print("Weights:", model.coef_)
# print("Bias:", model.intercept_)
#
# These correspond to:
#
# 𝑦
# =
# 𝑤
# 1
# 𝑥
# 1
# +
# 𝑤
# 2
# 𝑥
# 2
# +
# 𝑏
# y=w
# 1
# 	​
#
# x
# 1
# 	​
#
# +w
# 2
# 	​
#
# x
# 2
# 	​
#
# +b
# Step 7 — Visual Check
#
# You can compare actual vs predicted values.
#
# import matplotlib.pyplot as plt
#
# plt.scatter(y_test, y_pred)
# plt.xlabel("Actual Price")
# plt.ylabel("Predicted Price")
# plt.title("Actual vs Predicted")
# plt.show()
#
# Good models produce points close to the diagonal line.
#
# What You Will Learn
#
# After completing this task, you will understand:
#
# the standard ML workflow
#
# how libraries implement models
#
# how training and testing are separated
#
# how to evaluate model performance
#
# Day 6 Report
#
# Send:
#
# Day 6 update
#
# • What I studied:
# • What I built:
# • What I understood well:
# • What confused me:
# • Time spent:
#
# Also include:
#
# Weights:
# Bias:
# Mean Squared Error:

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

X = np.array([
    [1000, 3],
    [1200, 4],
    [1500, 4],
    [1800, 5]
])

y = np.array([50, 60, 70, 80])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Predicted values:", y_pred)

mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

print("Weights:", model.coef_)
print("Bias:", model.intercept_)

plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Linear Regression")
plt.show()
# Out:
# Predicted values: [55.]
# Mean Squared Error: 24.99999999999993
# Weights: [ 0.05 -5.  ]
# Bias: 15.000000000000007
