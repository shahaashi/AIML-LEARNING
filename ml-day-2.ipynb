# %% [markdown]
# Day 2 Problem Statement
#
# You will compute the same statistics using NumPy arrays instead of Python lists.
#
# Dataset:
#
# data = [10,20,30,40,50]
#
# Tasks:
#
# Convert the list into a NumPy array.
#
# Compute:
#
# mean
#
# variance
#
# standard deviation
#
# Normalize the dataset using NumPy operations.
#
# Print the results.
#
# New Concept You Must Learn
#
# Vectorization
#
# Instead of looping through elements, NumPy operates on entire arrays at once.
#
# Example:
#
# Python loop:
#
# for x in data:
#
# NumPy:
#
# array - mean
#
# Entire operation happens simultaneously.
#
# This is why ML libraries rely on NumPy.

# %%
import numpy as np 
data = np.array([10,20,30,40,50])

mean = np.mean(data)
print("Mean:", mean)    
variance = np.var(data)
print("Variance:", variance)
standard_deviation = np.std(data)
print("Standard Deviation:", standard_deviation)

normalized_data = (data - data.min()) / (data.max() - data.min())
print("Normalized Data:", normalized_data)

vector = data * 2
print("Vector (data multiplied by 2):", vector)
# Out:
# Mean: 30.0
# Variance: 200.0
# Standard Deviation: 14.142135623730951
# Normalized Data: [0.   0.25 0.5  0.75 1.  ]
# Vector (data multiplied by 2): [ 20  40  60  80 100]
